# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <center><h1 style="color:red;"><strong>Financial Economics 413 Lab #5a</strong></h1></center><br>
#     <center><h2><strong><color:red>Bond Valuations</h2></center></strong></h2></center><br>
# </div>

# %% [markdown]
# ### Data Dictionary
#
# This applies to several data sets you will import, but there may be some differences.
#
# | Variable  | Values | Source | Mnemonic |
# |-----------|--------|--------|----------|
# | Date      | Date string as YYYY-MM-DD | US Treasury, Table H.15 | Date |
# | 1 Month Government Securities Yield | Percent | IBID. | GS1M |
# | 2 Month Government Securities Yield | Percent | IBID. | GS2M |
# | 3 Month Government Securities Yield | Percent | IBID. | GS3M |
# | 4 Month Government Securities Yield | Percent | IBID. | GS4M |
# | 6 Month Government Securities Yield | Percent | IBID. | GS6M |
# | 1 Year Government Securities Yield  | Percent | IBID. | GS1  |
# | 2 Year Government Securities Yield  | Percent | IBID. | GS2  |
# | 3 Year Government Securities Yield  | Percent | IBID. | GS3  |
# | 5 Year Government Securities Yield  | Percent | IBID. | GS5  |
# | 7 Year Government Securities Yield  | Percent | IBID. | GS7  |
# | 10 Year Government Securities Yield  | Percent | IBID. | GS10 |
# | 20 Year Government Securities Yield  | Percent | IBID. | GS20 |
# | 30 Year Government Securities Yield  | Percent | IBID. | GS30 |

# %% [markdown]
# ### Bond Yield Curve Graphing

# %% [markdown]
# Graphs of the yield curve are important for bond market analysis as well as understanding the direction, present and future, of the economy.
#
# In this lab, you will create and interpret bond yield curves of Treasury T-Bonds of different maturities:  1 Month, 2 Months, 3 Months, 4 Months, 6 Months, 1 Year,	2 Years, 3 Years, 5 Years, 7 Years, 10 Years, 20 Years, and 30 Years.  I wrote a function that will import Treasury T-Bond yield curve data, process that data, and produce two graphs.  The first is based on the data as provided by the Treasury.  The second is based on the same data, but with an interpolation between the maturity dates since there obviously big gaps in the dates.
#
# Your assignment is to select several dates between 1/2/2020 and 10/13/2023, produce the yield curves using the function, and interpret the graphs.  You need to run the function several times with different dates to produce several graphs for patterns.  I suggest that you use dates that are widely spread out to increase you chances of seeing more patterns.
#
# I wrote the function to check for invalid dates (e.g., a weekend).  It will prompt you for another date if you enter an invalid date.

# %% [markdown]
# The daily yield curve data are from [here](https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2020).  The monthly numbers are arithmetic averages of the daily numbers.
#
# Some notes from the Treasury web site:
#
# The 4-month constant maturity series began on October 19, 2022, with the first auction of a 17-week Treasury bill as a benchmark Treasury security. Prior to this date, Treasury had issued Treasury bills with 17-week maturities as cash management bills.
#
# The 2-month constant maturity series began on October 16, 2018, with the first auction of the 8-week Treasury bill.
#
# 30-year Treasury constant maturity series was discontinued on February 18, 2002 and reintroduced on February 9, 2006. From February 18, 2002 to February 8, 2006, Treasury published alternatives to a 30-year rate. See Long-Term Average Rate for more information.
#
# Treasury discontinued the 20-year constant maturity series at the end of calendar year 1986 and reinstated that series on October 1, 1993. As a result, there are no 20-year rates available for the time-period January 1, 1987 through September 30, 1993.
#
# Treasury Par Yield Curve Rates: These rates are commonly referred to as "Constant Maturity Treasury" rates, or CMTs. Yields are interpolated by the Treasury from the daily par yield curve. This curve, which relates the yield on a security to its time to maturity, is based on the closing market bid prices on the most recently auctioned Treasury securities in the over-the-counter market. These par yields are derived from indicative, bid-side market price quotations (not actual transactions) obtained by the Federal Reserve Bank of New York at or near 3:30 PM each trading day. The CMT yield values are read from the par yield curve at fixed maturities, currently 1, 2, 3, 4 and 6 months and 1, 2, 3, 5, 7, 10, 20, and 30 years. This method provides a par yield for a 10-year maturity, for example, even if no outstanding security has exactly 10 years remaining to maturity.
#
# Treasury Par Yield Curve Methodology: The Treasury par yield curve is estimated daily using a monotone convex spline method. Inputs to the model are indicative bid-side prices for the most recently auctioned nominal Treasury securities. Treasury reserves the option to make changes to the yield curve as appropriate and in its sole discretion. See our Treasury Yield Curve Methodology page for details.
#
# Negative Yields and Nominal Constant Maturity Treasury Series Rates (CMTs): At times, financial market conditions, in conjunction with extraordinarily low levels of interest rates, may result in negative yields for some Treasury securities trading in the secondary market. Negative yields for Treasury securities most often reflect highly technical factors in Treasury markets related to the cash and repurchase agreement markets and are at times unrelated to the time value of money.
#
# At such times, Treasury will not restrict the use of prices that correspond to negative yields as inputs to the monotone convex spline method. However, the derived par yield curve from these input prices for the Treasury nominal Constant Maturity Treasury series (CMTs) will be floored at zero. This decision is consistent with Treasury not accepting negative yields in Treasury nominal security auctions.
#
# In addition, given that CMTs are used in many statutorily and regulatory determined loan and credit programs as well as for setting interest rates on non-marketable government securities, establishing a floor of zero more accurately reflects borrowing costs related to various programs.

# %% [markdown]
# The following function will process the data.  Run the following code cell just once to initialize it.  Go to the cell right after this function code cell.

# %%
##
## Yield Curve Function
##
## ===> Run this cell once <===
## ===> DO NOT ALTER THIS CELL <===
##
def yield_curve( data, date ):
    ##
    ## Subset the data for the date and plot the yield curve
    ## DO NOT CHANGE THE FOLLOWING CODE
    ##
    cols = data.columns
    data = { 'term':cols, 'yield': np.array( df.query( "Date == @date") )[ 0 ] }
    tmp = pd.DataFrame( data )
    tmp.set_index( 'term', inplace = True )
    display( tmp.T )
    tmp.plot( title = 'Yield Curve\n' + date, ylabel = 'Yield', xlabel = 'Term', legend = False );

# %% [markdown]
# Run the above code cell just once and then run the next cell multiple time by specifying a date to examine.  The date is a string in single or double quotes and in the form in the format of 'YYYY-MM-DD' or 'MM/DD/YYYY'.  Note the quotes.  For example, you can use '8/1/2001' or '2001/08/01'. The variable "data" is the name of your DataFrame, such as *df*.  But first, you have to import some data.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <font color = black>Exercises
# --------------------------------------
#
# </div>

# %% [markdown]
# ### Exercise 1
#
# Load the Pandas, Seaborn, and Matplotlib packages and give them an alias.  Also, set the graph style using the Seaborn *set* method.

# %%
##
## Enter the code here
##
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

import warnings
warnings.filterwarnings( "ignore" )

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf 
from statsmodels.iolib.summary2 import summary_col

# %% [markdown]
# ### Exercise 2
#
# Import the file *dailyYields.csv*.  Be sure to parse the *Date* variable to a datetime variable using *parse_dates = [ 'Date' ]* and then set the index to this variable.

# %%
df = pd.read_csv( 'dailyYields.csv', parse_dates = [ 'Date' ] )
df.set_index( 'Date', inplace = True )

# %% [markdown]
# ### Exercise 3
#
# Plot a yield curve for any date you want.  What do you see?
#
# **HINT**:  There has been a lot of press lately about the yield curve.  You should research some of this.

# %%
##
## Enter a date in the format of 'YYYY-MM-DD' or 'MM/DD/YYYY'.  Note the single quotes.  Examples formats are:
##    '2001-08-01', '8/1/2001', '08/01/2001'
##
date = '2001-08-01'
##date = '8/1/2001'
##date = '08/01/2001'
yield_curve( df, date )
# Out:
# term   GS1M  GS3M  GS6M   GS1   GS2   GS3   GS5  GS7  GS10  GS20  GS30
# yield  3.65  3.53  3.47  3.56  3.83  4.09  4.62  4.9  5.11  5.63  5.53

# %% [markdown]
# ### Exercise 4
#
# Import the Treasury security data in the *CSV* file *monthlyYields.csv*.  Parse the *Date* variable using *parse_dates[ 'Date' ]* to translate the date character string to a datetime variable.  Then plot all the series at once with just one call to the *plot* method.
#
# What do you see?  Interpret the graph.  There's a lot going on in this graph.

# %%
df = pd.read_csv( 'monthlyYields.csv', parse_dates = [ 'Date' ] )
df.set_index( 'Date', inplace = True )
display( df.head() )
ax = df.plot( title = 'Structure of Government Security Yields', ylabel = 'Yield (%)' )
ax.legend( loc = 'center left', bbox_to_anchor = ( 1.0, 0.5 ) );
# Out:
#             GS1M  GS3M  GS6M   GS1   GS2   GS3   GS5   GS7  GS10  GS20  GS30
# Date
# 2001-07-01  3.67  3.59  3.56  3.62  4.04  4.31  4.76  5.06  5.24  5.75  5.61
# 2001-08-01  3.53  3.44  3.39  3.47  3.76  4.04  4.57  4.84  4.97  5.58  5.48
# 2001-09-01  2.68  2.69  2.71  2.82  3.12  3.45  4.12  4.51  4.73  5.53  5.48
# 2001-10-01  2.27  2.20  2.17  2.33  2.73  3.14  3.91  4.31  4.57  5.34  5.32
# 2001-11-01  1.99  1.91  1.92  2.18  2.78  3.22  3.97  4.42  4.65  5.33  5.12

# %% [markdown]
# #### Graph interpretation
#  - the yields all move 'together' (increase together/decrease together)
# - the higher the yield, the longer the time to maturity
# - yield percentage generally decreased between 2004-2019, and had a sharp increase afterward
# - yield percentage had a sharp uptick around 2005

# %% [markdown]
# ### Exercise 5
#
# Use the DataFrame from Exercise 5 to create a correlation matrix.  Interpret the matrix.  What do you see?
#
# **HINT**: Use the DataFrame method *corr()*.

# %%
df.corr()
# Out:
#           GS1M      GS3M      GS6M       GS1       GS2       GS3       GS5  \
# GS1M  1.000000  0.996076  0.989139  0.978996  0.947668  0.911736  0.826413
# GS3M  0.996076  1.000000  0.997033  0.989246  0.959481  0.923231  0.834813
# GS6M  0.989139  0.997033  1.000000  0.996421  0.971521  0.937178  0.848913
# GS1   0.978996  0.989246  0.996421  1.000000  0.986612  0.959122  0.878117
# GS2   0.947668  0.959481  0.971521  0.986612  1.000000  0.991343  0.935887
# GS3   0.911736  0.923231  0.937178  0.959122  0.991343  1.000000  0.972167
# GS5   0.826413  0.834813  0.848913  0.878117  0.935887  0.972167  1.000000
# GS7   0.743664  0.749306  0.762286  0.794421  0.865990  0.919150  0.985049
# GS10  0.651574  0.654234  0.665986  0.698481  0.777185  0.841949  0.940563
# GS20  0.518003  0.517964  0.527597  0.560516  0.646301  0.722895  0.854485
# GS30  0.452585  0.448963  0.455133  0.486181  0.573270  0.654040  0.800349
#
#            GS7      GS10      GS20      GS30
# ...

# %% [markdown]
# #### Matrix Interpretation
# - as the difference between times to maturity increases, the correlation decreases

# %% [markdown]
# ### Exercise 6
#
# Interpret the regression model results.
#
# >- What do the tell you about the relationship between the Aaa bond yield and the three variables?
# >- What does the $R^2$ tell you?
# >- Which variables are statistically significant?
# >- Is the model statistically significant? (HINT: Look at the F-statistic)
# >- What does the Durbin-Watson Statistic tell you?
# >- Is this a good model?
# >- Can you think of any other macro variables to try?

# %%
df = pd.read_csv( 'lab2.csv', parse_dates = [ 'Date' ] )
df.head()
# Out:
#         Date       Open       High        Low      Close   adjClose  Urate  \
# 0 1960-01-01  59.910000  60.389999  55.610001  55.610001  55.610001    5.2
# 1 1960-02-01  55.959999  56.820000  54.730000  56.119999  56.119999    4.8
# 2 1960-03-01  56.009998  56.009998  53.470001  55.340000  55.340000    5.4
# 3 1960-04-01  55.430000  56.590000  54.369999  54.369999  54.369999    5.2
# 4 1960-05-01  54.130001  55.830002  54.130001  55.830002  55.830002    5.1
#
#     Indpro   AAA
# 0  24.1712  4.61
# 1  23.9561  4.56
# 2  23.7410  4.49
# 3  23.5528  4.45
# 4  23.5259  4.46

# %%
formula = 'AAA ~ Indpro + Urate + adjClose'

mod = smf.ols( formula, data = df )

reg01 = mod.fit()

display( reg01.summary() )
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    AAA   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     160.3
# Date:                Mon, 23 Oct 2023   Prob (F-statistic):           1.72e-80
# Time:                        07:22:43   Log-Likelihood:                -1657.1
# No. Observations:                 764   AIC:                             3322.
# Df Residuals:                     760   BIC:                             3341.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.4254      0.366     14.813      0.000       4.706       6.144
# ...

# %% [markdown]
# #### OLS analysis
# *What do the tell you about the relationship between the AAA bond yield and the three variables?*
# - they have a positive relationship
#
# *What does the  𝑅2 tell you?*
# - 38.8% of variation in AAA rating is explained by industrial production, unemployment rate, and prices
#
# *Which variables are statistically significant?*
# - urate, adjclose
#
# *Is the model statistically significant? (HINT: Look at the F-statistic)*
# - f-statistic is 160.3.
# - the probability of the f-statistic is close to 0, which means that the model is consistent with expectations.
#
# *What does the Durbin-Watson Statistic tell you?*
# - it reveals information about autocorrelation
# - in this case, the statistic (value = .018, which is less than 2.0) reveals that every value is positively correlated with its lagged value. An increase in the value of AAA rating in a given time interval is correlated to a proportional increase in the lagged interval.
#
# *Is this a good model?*
#
# Can you think of any other macro variables to try?

# %% [markdown]
# Create a correlation matrix of the four variables.  Interpret the matrix.  Does it suggest a potential problem for the regression model?  If yes, then what is the problem?
#
# What is the relationship between stock prices and the AAA rating?

# %%
cols = [ 'adjClose', 'Urate', 'Indpro', 'AAA' ]
df[ cols ].corr()
# Out:
#           adjClose     Urate    Indpro       AAA
# adjClose  1.000000 -0.236740  0.797956 -0.579537
# Urate    -0.236740  1.000000 -0.088703  0.345702
# Indpro    0.797956 -0.088703  1.000000 -0.395911
# AAA      -0.579537  0.345702 -0.395911  1.000000

# %% [markdown]
# #### correlation analysis
# - the relationship between closing prices and unemployment rate is -.23, which is small and negative. When closing prices increase, unemployment rate decreases by a small amount.
# - the relationship between closing prices and industrial production is .79, which is moderate and positive. When closing prices increase, unemployment rate increases by a moderate amount.
# - the relationship between closing prices and AAA is -.58, which is moderate and negative. When closing prices increase, unemployment rate decreases by a moderate amount.
